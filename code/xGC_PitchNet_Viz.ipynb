# %%
# %run xGC_PitchNet.ipynb

# %%
xGC_PitchNet('France',[1,2,3],pattern=3,p=0.95,title='France Group Phase Games 1,2 and 3 - xGC Pitch Network top 95% edges (pattern = 3)',save_fig='../viz/france123.png')
# Out:
# ()
